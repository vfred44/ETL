# %%
pip install requests
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 320.0 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 kB 329.0 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.8/124.8 kB 1.2 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 1.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 883.8 kB/s eta 0:00:000:01
# ...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip/_vendor/rich/console.py", line 1673, in print
#     extend(render(renderable, render_options))
# ...

# %%
import requests

def fetch_air_range(station_id, date_from, date_until):
    url = 'http://airviro.klab.ee/station/csv'
    data = {
        'filter[type]': 'INDICATOR',
        'filter[cancelSearch]': '',
        'filter[stationId]': station_id,
        'filter[dateFrom]': date_from,
        'filter[dateUntil]': date_until,
        'filter[submitHit]': '1',
        'filter[indicatorIds]': ''
    }
    response = requests.post(url, data)
    return response.text

import datetime

def get_first_and_last_day_of_month(year, month):
    # Get the first day of the month
    first_day = datetime.date(year, month, 1)

    # Get the number of days in the month
    if month == 12:
        num_days = 31
    else:
        num_days = (datetime.date(year, month+1, 1) - datetime.timedelta(days=1)).day

    # Get the last day of the month
    last_day = datetime.date(year, month, num_days)

    return first_day, last_day

# %% [markdown]
# Apply functions from the last cell to iterate over the moths of year 2022, fetch air quality infromation for each month and write it into a file.

# %%
year = 2022
for month in range(1, 13):
    first_day, last_day = get_first_and_last_day_of_month(year, month)
    print(first_day, last_day)

    data = fetch_air_range(8, first_day, last_day)
    with open(f'air_data/air_{year}_{month}.csv', 'w') as f:
        f.write(data)
# Out:
# 2022-01-01 2022-01-31
# 2022-02-01 2022-02-28
# 2022-03-01 2022-03-31
# 2022-04-01 2022-04-30
# 2022-05-01 2022-05-31
# 2022-06-01 2022-06-30
# 2022-07-01 2022-07-31
# 2022-08-01 2022-08-31
# 2022-09-01 2022-09-30
# 2022-10-01 2022-10-31
# 2022-11-01 2022-11-30
# 2022-12-01 2022-12-31

# %% [markdown]
# It would be cumbersome to check each individual month file. Stich them together into single year file.

# %%
data = []
for month in range(1, 13):
    with open(f'air_data/air_{year}_{month}.csv', 'r') as f:
        if month == 1:
            header = f.readline()
            data.append(header)
        else:
            f.readline()
        data.extend(f.readlines())

with open(f'air_data/air_{year}.csv', 'w') as f:
    f.writelines(data)

# %%
pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 1.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 1.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 1.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 1.6 MB/s eta 0:00:0000:0100:01
# ...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip/_vendor/rich/console.py", line 1673, in print
#     extend(render(renderable, render_options))
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip/_vendor/rich/console.py", line 1305, in render
# ...

# %%
import pandas as pd
df = pd.read_csv("/Users/fredvaartnou/Andmetehnika/air_data/air_2022.csv")

#DateTime veeru teisendus
df["datetime"] = pd.to_datetime(df["DateTime"])

df
# Out:
#                   DateTime  SO2   NO2    CO    O3  PM10  PM2.5  TEMP   WD10
# 0     2022-01-31T23:00:00Z  0.7   6.8  0.28  43.0   9.0    5.9  -2.5  313.0  \
# 1     2022-01-31T22:00:00Z  0.9   9.6  0.30  40.5   8.6    5.5  -2.3  306.0
# 2     2022-01-31T21:00:00Z  1.1  12.6  0.33  37.0   8.6    5.5  -2.2  312.0
# 3     2022-01-31T20:00:00Z  1.1  15.5  0.32  34.4   7.8    4.7  -2.1  319.0
# 4     2022-01-31T19:00:00Z  0.9  16.6  0.30  35.2   7.0    4.0  -2.0  326.0
# ...                    ...  ...   ...   ...   ...   ...    ...   ...    ...
# 8753  2022-12-01T04:00:00Z  0.3   8.4  0.21  17.5  14.4    9.4  -3.1   75.0
# 8754  2022-12-01T03:00:00Z  0.3   4.9  0.22  19.5  15.6   10.2  -3.1  349.0
# 8755  2022-12-01T02:00:00Z  0.4   8.4  0.25  17.4  15.6   10.2  -3.0  205.0
# 8756  2022-12-01T01:00:00Z  0.5   8.0  0.26  18.4  18.0   12.6  -3.1  137.0
# 8757  2022-12-01T00:00:00Z  0.3  14.6  0.27  13.3  20.3   14.9  -2.7  106.0
#
#       WS10                  datetime
# ...

# %%
#Kuu keskmiste arvutused

SO2 = df.groupby(df.datetime.dt.month)['SO2'].mean()
NO2 = df.groupby(df.datetime.dt.month)['NO2'].mean()
CO = df.groupby(df.datetime.dt.month)['CO'].mean()
O3 = df.groupby(df.datetime.dt.month)['O3'].mean()
PM10  = df.groupby(df.datetime.dt.month)['PM10'].mean()
PM25 = df.groupby(df.datetime.dt.month)['PM2.5'].mean()
TEMP = df.groupby(df.datetime.dt.month)['TEMP'].mean()
WD10 = df.groupby(df.datetime.dt.month)['WD10'].mean()
WS10 = df.groupby(df.datetime.dt.month)['WS10'].mean()

# %%
#Kuu keskmiste dataframei loomine

df2 = pd.concat([SO2, NO2, CO, O3, PM10, PM25, TEMP, WD10, WS10], axis=1)
df2
# Out:
#                SO2        NO2        CO         O3       PM10     PM2.5
# datetime
# 1         0.611440  11.716981  0.333441  48.458839   9.730135  6.609054  \
# 2         0.440030  10.883780  0.346726  57.378274  11.696726  7.201042
# 3         0.618674  16.442355  0.439729  61.710163  26.300951  9.894452
# 4         0.385396   7.137744  0.272806  68.800836  16.253621  4.103056
# 5         0.227419   5.409812  0.207352  66.276210  12.989204  3.096496
# 6         0.295417   4.686752  0.190083  57.260313  14.156625  5.202092
# 7         0.163478   3.825337  0.168506  52.174089  10.894189  2.969324
# 8         0.368280   6.294482  0.204987  49.482258  18.449194  5.413306
# 9         0.317361   7.152083  0.235833  29.828611   8.676389  2.728472
# 10        0.315054   9.467116  0.293306  31.589488  12.745148  5.502426
# 11        0.303333   8.658368  0.260042  28.876111   9.551604  4.740808
# 12        0.444489  14.536290  0.366075  33.977957  14.115457  9.706586
#
# ...

# %%
#Kuu keskmiste csv export

df2.to_csv('monthly_average.csv')

# %%
#Kuupäevast ja kellaajast eraldi veerud

df['Date'] = pd.to_datetime(df['datetime']).dt.date
df['Time'] = pd.to_datetime(df['datetime']).dt.time
df
# Out:
#                   DateTime  SO2   NO2    CO    O3  PM10  PM2.5  TEMP   WD10
# 0     2022-01-31T23:00:00Z  0.7   6.8  0.28  43.0   9.0    5.9  -2.5  313.0  \
# 1     2022-01-31T22:00:00Z  0.9   9.6  0.30  40.5   8.6    5.5  -2.3  306.0
# 2     2022-01-31T21:00:00Z  1.1  12.6  0.33  37.0   8.6    5.5  -2.2  312.0
# 3     2022-01-31T20:00:00Z  1.1  15.5  0.32  34.4   7.8    4.7  -2.1  319.0
# 4     2022-01-31T19:00:00Z  0.9  16.6  0.30  35.2   7.0    4.0  -2.0  326.0
# ...                    ...  ...   ...   ...   ...   ...    ...   ...    ...
# 8753  2022-12-01T04:00:00Z  0.3   8.4  0.21  17.5  14.4    9.4  -3.1   75.0
# 8754  2022-12-01T03:00:00Z  0.3   4.9  0.22  19.5  15.6   10.2  -3.1  349.0
# 8755  2022-12-01T02:00:00Z  0.4   8.4  0.25  17.4  15.6   10.2  -3.0  205.0
# 8756  2022-12-01T01:00:00Z  0.5   8.0  0.26  18.4  18.0   12.6  -3.1  137.0
# 8757  2022-12-01T00:00:00Z  0.3  14.6  0.27  13.3  20.3   14.9  -2.7  106.0
#
# ...

# %%
#Date veerg datetime tyybiks

df['Date'] = pd.to_datetime(df['Date'])

# %%
print (df.dtypes)
# Out:
# DateTime                 object
# SO2                     float64
# NO2                     float64
# CO                      float64
# O3                      float64
# PM10                    float64
# PM2.5                   float64
# TEMP                    float64
# WD10                    float64
# WS10                    float64
# datetime    datetime64[ns, UTC]
# Date             datetime64[ns]
# Time                     object
# dtype: object

# %%
#Iga p2eva keskmiste v22rtuste arvutus

df3 = df.groupby("Date").agg({'SO2': 'mean', 'NO2': 'mean', 'CO': 'mean', 'O3': 'mean', 'PM10': 'mean', 'PM2.5': 'mean', 'TEMP': 'mean', 'WD10': 'mean', 'WS10': 'mean'})
print(daily.head())
# Out:
#                  SO2        NO2        CO         O3       PM10     PM2.5
# Date
# 2022-01-01  0.845833   6.633333  0.291667  44.854167   7.204167  5.970833  \
# 2022-01-02  0.566667  11.183333  0.331250  48.416667   8.075000  5.641667
# 2022-01-03  0.683333  10.791667  0.326250  42.058333   6.545833  5.091667
# 2022-01-04  0.812500  19.579167  0.446667  31.195833  10.775000  7.612500
# 2022-01-05  0.637500  11.362500  0.367083  46.258333   9.133333  7.887500
#
#                 TEMP        WD10      WS10
# Date
# 2022-01-01 -2.433333  301.541667  1.454167
# 2022-01-02 -7.670833  175.750000  1.704167
# 2022-01-03 -3.441667  142.458333  1.433333
# 2022-01-04  2.108333  169.666667  1.187500
# 2022-01-05  1.862500  180.708333  1.366667

# %%
#P2eva keskmiste csv export

df3.to_csv('daily_average.csv')
